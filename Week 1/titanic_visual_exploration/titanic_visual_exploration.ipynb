# %% [markdown]
# # Titanic visual exploration exercise

# %% [markdown]
# There exists an exhaustive record of who was onboard of the Titanic, and whether they survived or not to the sinking of the ship [1].
#
# The file 'data/titanic.csv' contains a table with 9 columns:
# * survived: 1 if passenger survived, 0 otherwise
# * name: Name of the passenger
# * sex: "male" or "female"
# * age: Age of the passenger
# * fare: Fare paid to travel on the Titanic
# * class: "First", "Second", or "Third" class
# * who: "child", "man", or "woman"
# * adult_male: True if the passenger is an adult male (i.e., who == "man")
# * alive: "yes" if the passenger survived the sinking, "no" otherwise
#
# Use pandas, seaborn, and matplotlib to find out more about the passengers and their destiny:
#
# 1) Load the file 'data/titanic.csv' in a DataFrame
#
# 2) Show the number of children, men, and women on board as a bar plot
#
# 3) Show the number of adult males vs non-adult males, split by the class they were travelling in.
#
# * Hint: Use the `order` keyword argument to order the classes as First, Second, Third.
#
# 4) Create a grid of plots showing the distribution of the age of the passengers, grouped by class (rows) and sex (columns)
#
# 5) Create a violin plot of fare price, grouped by class
#
# 6) Show the fraction of people who survived, for each of the classes.
#
# *   Hint 1: The fraction of survivors per class is equal to the mean of the `survived` indicator variable, per class. (This is a common trick.)
#
# *   Hint 2: Create a `factorplot` of `'survived`' vs `'class'`, setting `kind='bar'` (display the fraction of survivor as a bar plot), and `ci=None` (remove the error bars, which are meaningless).
#
# 7) Create a row of plots showing the fraction of survivors in each class. Each plot should contain the data for children, men, or women
#
# [1] http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic.html

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %%
# 1) Load the file 'data/titanic.csv' in a DataFrame
pd.read_table('titanic.csv', delimiter=',')
# Out:
#      Unnamed: 0  survived                                               name  \
# 0             0         0                            Braund, Mr. Owen Harris
# 1             1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             2         1                             Heikkinen, Miss. Laina
# 3             3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4             4         0                           Allen, Mr. William Henry
# 5             5         0                                   Moran, Mr. James
# 6             6         0                            McCarthy, Mr. Timothy J
# 7             7         0                     Palsson, Master. Gosta Leonard
# 8             8         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             9         1                Nasser, Mrs. Nicholas (Adele Achem)
# 10           10         1                    Sandstrom, Miss. Marguerite Rut
# 11           11         1                           Bonnell, Miss. Elizabeth
# 12           12         0                     Saundercock, Mr. William Henry
# 13           13         0                        Andersson, Mr. Anders Johan
# 14           14         0               Vestrom, Miss. Hulda Amanda Adolfina
# 15           15         1                   Hewlett, Mrs. (Mary D Kingcome)
# 16           16         0                               Rice, Master. Eugene
# 17           17         1                       Williams, Mr. Charles Eugene
# 18           18         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19           19         1                            Masselmani, Mrs. Fatima
# 20           20         0                               Fynney, Mr. Joseph J
# 21           21         1                              Beesley, Mr. Lawrence
# 22           22         1                        McGowan, Miss. Anna "Annie"
# 23           23         1                       Sloper, Mr. William Thompson
# 24           24         0                      Palsson, Miss. Torborg Danira
# 25           25         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia
# 12     male  20.0    8.0500   Third    man       True    no
# 13     male  39.0   31.2750   Third    man       True    no
# 14   female  14.0    7.8542   Third  child      False    no
# 15   female  55.0   16.0000  Second  woman      False   yes
# 16     male   2.0   29.1250   Third  child      False    no
# 17     male   NaN   13.0000  Second    man       True   yes
# 18   female  31.0   18.0000   Third  woman      False    no
# 19   female   NaN    7.2250   Third  woman      False   yes
# 20     male  35.0   26.0000  Second    man       True    no
# 21     male  34.0   13.0000  Second    man       True   yes
# 22   female  15.0    8.0292   Third  child      False   yes
# 23     male  28.0   35.5000   First    man       True   yes
# 24   female   8.0   21.0750   Third  child      False    no
# 25   female  38.0   31.3875   Third  woman      False   yes
# 26     male   NaN    7.2250   Third    man       True    no
# 27     male  19.0  263.0000   First    man       True    no
# 28   female   NaN    7.8792   Third  woman      False   yes
# 29     male   NaN    7.8958   Third    man       True    no
# ..      ...   ...       ...     ...    ...        ...   ...
# 861    male  21.0   11.5000  Second    man       True    no
# 862  female  48.0   25.9292   First  woman      False   yes
# 863  female   NaN   69.5500   Third  woman      False    no
# 864    male  24.0   13.0000  Second    man       True    no
# 865  female  42.0   13.0000  Second  woman      False   yes
# 866  female  27.0   13.8583  Second  woman      False   yes
# 867    male  31.0   50.4958   First    man       True    no
# 868    male   NaN    9.5000   Third    man       True    no
# 869    male   4.0   11.1333   Third  child      False   yes
# 870    male  26.0    7.8958   Third    man       True    no
# 871  female  47.0   52.5542   First  woman      False   yes
# 872    male  33.0    5.0000   First    man       True    no
# 873    male  47.0    9.0000   Third    man       True    no
# 874  female  28.0   24.0000  Second  woman      False   yes
# 875  female  15.0    7.2250   Third  child      False   yes
# 876    male  20.0    9.8458   Third    man       True    no
# 877    male  19.0    7.8958   Third    man       True    no
# 878    male   NaN    7.8958   Third    man       True    no
# 879  female  56.0   83.1583   First  woman      False   yes
# 880  female  25.0   26.0000  Second  woman      False   yes
# 881    male  33.0    7.8958   Third    man       True    no
# 882  female  22.0   10.5167   Third  woman      False    no
# 883    male  28.0   10.5000  Second    man       True    no
# 884    male  25.0    7.0500   Third    man       True    no
# 885  female  39.0   29.1250   Third  woman      False    no
# 886    male  27.0   13.0000  Second    man       True    no
# 887  female  19.0   30.0000   First  woman      False   yes
# 888  female   NaN   23.4500   Third  woman      False    no
# 889    male  26.0   30.0000   First    man       True   yes
# 890    male  32.0    7.7500   Third    man       True    no
#
# [891 rows x 10 columns]

# %%
#2) Show the number of children, men, and women on board as a bar plot
df = pd.read_table('titanic.csv', delimiter=',')

sns.countplot('who', data = df)
plt.show()

# %%
#3) Show the number of adult males vs non-adult males, split by the class they were travelling in.
# Hint: Use the order keyword argument to order the classes as First, Second, Third.
