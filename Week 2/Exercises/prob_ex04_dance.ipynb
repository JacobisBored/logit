# %% [markdown]
# # Probability Exercise 4: Dance Partners
#
# If you go to a dance where partners are paired up randomly, what portion of the opposite-sex couples will have the women taller than the men?
#
# Men: Mean = 178 cm, Variance = 59.4 cm
#
# Women: Mean = 163 cm, Variance = 52.8 cm
#
# Simulate this situation with 10000 couples and see how the result compares to your answer.

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Your code here

n = 10000
mean_w = 163
mean_m = 178
std_w = np.sqrt(52.8)
std_m = np.sqrt(59.4)

men = np.random.normal(mean_m, std_m, n)
women = np.random.normal(mean_w, std_w, n)

# %%
plt.hist(men)
# Out:
# (array([    7.,    75.,   554.,  1691.,  3012.,  2805.,  1435.,   364.,
#            51.,     6.]),
#  array([ 147.35508922,  153.60562784,  159.85616646,  166.10670507,
#          172.35724369,  178.60778231,  184.85832093,  191.10885955,
#          197.35939816,  203.60993678,  209.8604754 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(women)
# Out:
# (array([    4.,    50.,   297.,  1216.,  2505.,  3005.,  1999.,   767.,
#           141.,    16.]),
#  array([ 132.975294  ,  138.65696599,  144.33863797,  150.02030996,
#          155.70198195,  161.38365394,  167.06532592,  172.74699791,
#          178.4286699 ,  184.11034188,  189.79201387]),
#  <a list of 10 Patch objects>)

# %%
zip(men,women)
# Out:
# [(184.67788389670588, 171.27968057720591),
#  (174.74772427199946, 168.35314792366313),
#  (177.60179461561466, 153.427877104234),
#  (188.24296917120478, 170.3613419410224),
#  (182.47946178684793, 160.49818109743694),
#  (174.01149376506049, 168.20210442075194),
#  (184.44234237601543, 147.6631854412264),
#  (183.59433749733975, 170.86867394870478),
#  (186.27917465042029, 169.59713692352852),
#  (186.62870625427368, 153.328720230507),
#  (193.71133910134441, 159.09588459983917),
#  (173.37976900286341, 157.28055001590087),
#  (172.29242434616293, 172.21394236411871),
#  (170.80051247879132, 160.96863695017143),
#  (190.73571186470326, 157.3505145765503),
#  (179.1140257065542, 171.80003130755728),
#  (168.49046403308736, 166.45939017341209),
#  (187.71434511653396, 170.26270523298103),
#  (176.72028020504516, 158.30275878412243),
#  (184.14237692936385, 155.472445552051),
#  (178.26719522608846, 170.17787563432032),
#  (184.6037005732137, 164.43425521488788),
# ...

# %%
(women > men).sum()
# Out:
# 754
